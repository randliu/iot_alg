# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import axes3d

# %%
import sys

# %%
sys.path.append("/Users/rand/Code/PycharmProjects/vibration_algorithm/")

# %%
from data_index import index

# %%
import csv

# %%
acc = pd.read_csv('acc.csv')

# %%
X=acc['X']

# %%
Y=acc['Y']

# %%
Z=acc['Z']

# %%
v_x = index.acc_to_v_with_bonferroni(X)
s_x =  index.v_to_movement_with_bonferroni(v_x)

# %%
v_y = index.acc_to_v_with_bonferroni(Y)
s_y =  index.v_to_movement_with_bonferroni(v_y)

v_z = index.acc_to_v_with_bonferroni(Z)
s_z =  index.v_to_movement_with_bonferroni(v_z)

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

# set figure information
ax.set_title("3D_Curve")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
figure = ax.plot(s_x, s_y, s_z)

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

# set figure information
ax.set_title("3D_Curve")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
figure = ax.plot(v_x, v_y,v_z)

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

# set figure information
ax.set_title("3D_Curve")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
figure = ax.plot(X, Y,Z)

# %%
plt.plot(s_x,s_y,'black')

# %%
plt.plot(s_x,s_z,'black')

# %%
plt.plot(s_y,s_z,'black')

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

# set figure information
ax.set_title("3D_Curve")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
s_x2=s_x-np.mean(s_x)
s_y2=s_y-np.mean(s_y)
s_z2=s_z-np.mean(s_z)




figure = ax.plot(s_x2, s_y2, s_z2)
